# %%
import pandas as pd
import numpy as np
import os

### 0000320193-17-000070,AAPL,320193,10-K,2017-11-03 00:00:00,2017-11-03 08:01:37
### 24937,540777466,1334081,"Apple Inc., Q4 2017 Earnings Call, Nov 02, 2017",20171102,21:00:00,48,Earnings Calls,Apple Inc.,8,Audited Copy,5,Final,20171106,21:14:02,3488,0,

earnings_embedding = np.load('../sample/transcripts/1334081_embedding.npy', allow_pickle=True).item()
k_item1a = pd.read_csv('../sample/sec-filings/0000320193/10-K/0000320193-17-000070/embedding_item1a.csv')
k_item7 = pd.read_csv('../sample/sec-filings/0000320193/10-K/0000320193-17-000070/embedding_item7.csv')
k_item7a = pd.read_csv('../sample/sec-filings/0000320193/10-K/0000320193-17-000070/embedding_item7a.csv')
data = pd.read_feather('../sample/transcripts/1334081.feather')

# %%
data
# Out:
#     transcriptid  transcriptcomponentid  componentorder  \
# 0      1334081.0             53556946.0             0.0
# 1      1334081.0             53556947.0             1.0
# 2      1334081.0             53556948.0             2.0
# 3      1334081.0             53556949.0             3.0
# 4      1334081.0             53556950.0             4.0
# 5      1334081.0             53556951.0             5.0
# 6      1334081.0             53556952.0             6.0
# 7      1334081.0             53556953.0             7.0
# 8      1334081.0             53556954.0             8.0
# 9      1334081.0             53556955.0             9.0
# 10     1334081.0             53556956.0            10.0
# 11     1334081.0             53556957.0            11.0
# 12     1334081.0             53556958.0            12.0
# 13     1334081.0             53556959.0            13.0
# 14     1334081.0             53556960.0            14.0
# 15     1334081.0             53556961.0            15.0
# ...
