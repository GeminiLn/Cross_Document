# %%
import pandas as pd
import numpy as np
import json
import os

### 0000320193-17-000070,AAPL,320193,10-K,2017-11-03 00:00:00,2017-11-03 08:01:37
### 24937,540777466,1334081,"Apple Inc., Q4 2017 Earnings Call, Nov 02, 2017",20171102,21:00:00,48,Earnings Calls,Apple Inc.,8,Audited Copy,5,Final,20171106,21:14:02,3488,0,

# 10-K concepts
concepts_item1a = pd.read_csv('../data/sample/sec-filings/0000320193/10-K/0000320193-17-000070/concept_item1a.csv')
concepts_item7 = pd.read_csv('../data/sample/sec-filings/0000320193/10-K/0000320193-17-000070/concept_item7.csv')
concepts_item7a = pd.read_csv('../data/sample/sec-filings/0000320193/10-K/0000320193-17-000070/concept_item7a.csv')

# EC concepts
ec = pd.read_feather('../data/sample/transcripts/1334081.feather')
ec_json = json.load(open('../data/sample/transcripts/1334081_concepts.json'))

# %%
ec_json.keys()
# Out:
# dict_keys(['53556947', '53556948', '53556949', '53556950', '53556952', '53556954', '53556957', '53556959', '53556962', '53556964', '53556967', '53556969', '53556972', '53556974', '53556977', '53556980', '53556982', '53556985', '53556987'])

# %%
concepts_ec = []
for key in ec_json.keys():
    concepts_ec = concepts_ec + ec_json[key]
concepts_ec = pd.DataFrame(concepts_ec)

# %%
concepts_pool = pd.concat([concepts_item1a, concepts_item7, concepts_item7a, concepts_ec])

# %%
concepts_ec
# Out:
#          0         1         2         3         4         5         6    \
# 0   0.009149 -0.215993 -0.232858 -0.081878  0.144253  0.203399  0.263103
# 1  -0.003814 -0.224977 -0.235151 -0.113665  0.178190  0.192621  0.264188
# 2   0.004310 -0.217395 -0.218245 -0.092730  0.139454  0.192163  0.265599
# 3  -0.009190 -0.207212 -0.220878 -0.091655  0.189830  0.207397  0.251952
# 4   0.000121 -0.218884 -0.224766 -0.086515  0.141165  0.198892  0.255008
# ..       ...       ...       ...       ...       ...       ...       ...
# 56  0.010239 -0.218322 -0.220103 -0.118260  0.137906  0.218782  0.269737
# 57 -0.001607 -0.216288 -0.220372 -0.076973  0.131496  0.196336  0.257868
# 58 -0.004108 -0.255986 -0.218766 -0.098810  0.183396  0.220000  0.302597
# 59 -0.001301 -0.205592 -0.225172 -0.092348  0.136484  0.201843  0.258757
# 60 -0.006333 -0.236829 -0.243994 -0.133755  0.187571  0.221679  0.287797
#
#          7         8         9    ...       758       759       760       761  \
# 0  -0.088554 -0.068129 -0.171872  ...  0.008100  0.031334 -0.099970  0.266216
# 1  -0.069061 -0.102193 -0.176802  ...  0.025171  0.073368 -0.098454  0.247668
# 2  -0.083637 -0.065145 -0.189645  ...  0.020305  0.045047 -0.085726  0.242861
# 3  -0.054414 -0.093316 -0.192344  ...  0.018398  0.038791 -0.098646  0.279370
# 4  -0.077269 -0.059591 -0.162764  ...  0.015766  0.035837 -0.101435  0.252479
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 56 -0.059353 -0.080566 -0.191057  ...  0.009950  0.021956 -0.122448  0.284904
# 57 -0.068197 -0.065006 -0.163069  ...  0.011428  0.025236 -0.098948  0.251918
# 58 -0.027639 -0.091179 -0.214933  ...  0.021255  0.004257 -0.129159  0.310675
# 59 -0.089473 -0.060442 -0.163655  ...  0.015255  0.025936 -0.097890  0.259831
# 60 -0.046631 -0.083083 -0.215517  ...  0.023367  0.032120 -0.145994  0.320406
#
#          762       763       764       765       766       767
# 0   0.217048 -0.284488  0.137203 -0.145278 -0.043262 -0.108041
# 1   0.183531 -0.318627  0.119283 -0.152851 -0.067872 -0.152441
# 2   0.173190 -0.275779  0.138016 -0.133899 -0.041639 -0.121968
# 3   0.198015 -0.329095  0.070106 -0.158046 -0.072806 -0.163290
# 4   0.192582 -0.275410  0.131461 -0.146210 -0.037334 -0.112370
# ..       ...       ...       ...       ...       ...       ...
# 56  0.201375 -0.320268  0.090767 -0.180240 -0.065294 -0.122072
# 57  0.198638 -0.269812  0.130145 -0.140589 -0.035021 -0.119016
# 58  0.206355 -0.363244  0.062779 -0.177854 -0.040115 -0.142933
# 59  0.203525 -0.281778  0.135280 -0.127535 -0.042020 -0.110004
# 60  0.222472 -0.369481  0.047443 -0.206632 -0.063421 -0.158633
#
# [61 rows x 768 columns]

# %%
# 1. Too many concepts for earnings call
# 2. Each round have two or three concepts, which seems not necessary
# 3. Unbalanced concepts pool
